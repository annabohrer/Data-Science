# %% [markdown]
# <a href="https://colab.research.google.com/github/annabohrer/Data-Science/blob/main/Bohrer_AI_Stats_Lab_6_Linear_Fit_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                                                              #importing outside programs into python
import matplotlib.pyplot as plt

import pandas as pd
import urllib.request

# %%
url = "https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv"       #using data from this url

# %%
urllib.request.urlretrieve(url,'cereal_data.csv')                               #retrieving the data from the site
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f48e99520a0>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')                                    #telling python to read the data and show it here

# %%
cereal_data                                                                     #printing the data from the url
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"]                                                           #printing only the data about sugars
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
#       ..
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
cereal_data[["calories", "sugars"]]                                             #printing both the calories data and the sugars data
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
cereal_data["sugars"].mean()                                                    #finding the mean of the sugars data
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean()                                      #finding both means from both sets of data
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()                                                          #describing all the data like the mean and standard deviation and percentages
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
plt.plot(cereal_data[["sugars"]], cereal_data[["calories"]], '.')               #ploting the data of both sugars and calories

# %%
x = cereal_data[["sugars"]]                                                     #x axis is sugars
y = cereal_data[["calories"]]                                                   #y axis is calories

plt.plot(x,y,'.')                                                               #ploting x and y with dots
plt.xlabel("Sugars")                                                            #labels
plt.ylabel("Calories")
plt.title("Sugar vs Calories")                                                  #title
# Out:
# Text(0.5, 1.0, 'Sugar vs Calories')

# %%
x = cereal_data[["protein"]]                                                    #defining x and y
y = cereal_data[["fat"]]

plt.plot(x,y,'.')                                                               #plotting x and y with dots
plt.xlabel("Protein")                                                           #labels
plt.ylabel("Fat")
plt.title("Protein vs Fat")                                                     #title of the graph
# Out:
# Text(0.5, 1.0, 'Protein vs Fat')

# %%
from sklearn.linear_model import LinearRegression                               #importing an outside program
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(x, y)                                                      #creating a line of regression and best fit of an x and y
_pred = linear_regressor.predict(x)

# %%
x = np.linspace(0,10,50)                                                        #creating an array with spaces
                                                                                #the numbers from 0 to 10 50 times

# %%
x                                                                               #showing what x is defined as
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
m = 3                                                                           #the slope
b = 7                                                                           #the y intercept

y = m * x + b                                                                   #the equation

# %%
noise = 10 * np.random.randn(50,)                                               #defining noise

# %%
y = m * x +b + noise                                                            #equation plus what noise is defined as

# %%
plt.plot(x,y,'.')                                                               #ploting x and y with dots

# %%
m_guess = 5                                                                     #the best guess for m and b which are the slope and y intercept
b_guess = 15

y_guess = m_guess * x + b_guess                                                 #new equation defining y guess
plt.plot(x,y_guess, 'r.');                                                      #plotting x and the new y with red dots
plt.plot(x,y, 'g.')                                                             #plotting the original with green dots

# %%
loss= np.sum((y_guess - y)**2)                                                  #the loss equals the numpy sum which is the y guess (the new y) squared

# %%
for m_guess in np.linspace(-10,10,10):                                          #when the guess is between -10 and 10 (linspace 10 so it will be shown 10 times)
    print(m_guess)                                                              #print the m guess
# Out:
# -10.0
# -7.777777777777778
# -5.555555555555555
# -3.333333333333333
# -1.1111111111111107
# 1.1111111111111107
# 3.333333333333334
# 5.555555555555557
# 7.777777777777779
# 10.0

# %%
for m_guess in np.linspace(-10, 10,10):                                         #when m guess is between -10 and 10
    for b_guess in np.linspace(-10,10,10):                                      #and when b guess is between -10 and 10

      y_guess = m_guess * x + b_guess                                           #use this equation

      plt.plot(x,y_guess, 'r.');                                                #plot x and y guess with red dots
      plt.plot(x,y,'g.');                                                       #and plot x and y with green dots
      plt.show()                                                                #show the graph

      loss = np.sum((y_guess - y)**2)                                           #use the loss equation from before

      print(loss,m_guess,b_guess)                                               #print the loss then the m guess and then the b guess in that order
# Out:
# 422895.56455254176 -10.0 -10.0
# 404747.16415355937 -10.0 -7.777777777777778
# 387092.59091507085 -10.0 -5.555555555555555
# 369931.8448370761 -10.0 -3.333333333333333
# 353264.9259195752 -10.0 -1.1111111111111107
# 337091.8341625682 -10.0 1.1111111111111107
# 321412.56956605497 -10.0 3.333333333333334
# 306227.13213003555 -10.0 5.555555555555557
# 291535.52185451 -10.0 7.777777777777779
# 277337.73873947834 -10.0 10.0
# 314065.2237349495 -7.777777777777778 -10.0
# 298385.9591384362 -7.777777777777778 -7.777777777777778
# 283200.5217024168 -7.777777777777778 -5.555555555555555
# 268508.9114268913 -7.777777777777778 -3.333333333333333
# 254311.12831185956 -7.777777777777778 -1.1111111111111107
# 240607.1723573216 -7.777777777777778 1.1111111111111107
# 227397.04356327755 -7.777777777777778 3.333333333333334
# 214680.7419297273 -7.777777777777778 5.555555555555557
# 202458.26745667087 -7.777777777777778 7.777777777777779
# 190729.6201441083 -7.777777777777778 10.0
# ...

# %%
best_loss = 1000                                                                #if the best loss is 1000
best_n = 0                                                                      #the n is 0
best_b = 0                                                                      #the b is also 0
for m_guess in np.linspace(-10,10,20):                                          #if the m guess is between -10 and 10 (linspace is 20 so it is shown 20 times)
    for b_guess in np.linspace(-10,10,20):                                      #if the b guess is between -10 and 10

      y_guess = m_guess * x + b_guess                                           #using this equation

      loss = np.sum((y_guess - y)**2)                                           #what the loss will equal

      if loss < best_loss:                                                      #if the loss that was from the equation is less than the best loss which was defined above

          best_loss = loss                                                      #the best loss will equal the loss
          best_m = m_guess                                                      #the best m will equal the guess
          best_b = b_guess                                                      #the best b will equal the guess

          plt.plot(x,y_guess,'r.');                                             #plotting x and y guess with red dots
          plt.plot(x,y,'g.')                                                    #plotting x and y with green dots
          plt.show                                                              #show the graph

          print(loss,m_guess,b_guess)                                           #print the loss m guess and b guess in that order
